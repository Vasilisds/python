# %%
import pandas as pd
import os

# %%
files = [file for file in os.listdir(r"C:\Users\Nomitech\Desktop\Datascience project")]
all_months_data = pd.DataFrame()
for file in files:
    df=pd.read_csv(r'C:\Users\Nomitech\Desktop\Datascience project/' + file)
    all_months_data = pd.concat([all_months_data,df])

all_months_data.to_csv("all_data.csv",index=False)

# %%
df = pd.read_csv("all_data.csv")

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df.drop(index = df.index[1],axis = 0,inplace=True)

# %%
df = df.reset_index()

# %%
df
# Out:
#          index Order ID                     Product Quantity Ordered  \
# 0            0   176558        USB-C Charging Cable                2
# 1            2   176559  Bose SoundSport Headphones                1
# 2            3   176560                Google Phone                1
# 3            4   176560            Wired Headphones                1
# 4            5   176561            Wired Headphones                1
# ...        ...      ...                         ...              ...
# 186844  186845   259353      AAA Batteries (4-pack)                3
# 186845  186846   259354                      iPhone                1
# 186846  186847   259355                      iPhone                1
# 186847  186848   259356      34in Ultrawide Monitor                1
# 186848  186849   259357        USB-C Charging Cable                1
#
#        Price Each      Order Date                         Purchase Address
# ...

# %%
###What was the Best Month for sales,How Much was earned that month?
df.head()
# Out:
#    index Order ID                     Product Quantity Ordered Price Each  \
# 0      0   176558        USB-C Charging Cable                2      11.95
# 1      2   176559  Bose SoundSport Headphones                1      99.99
# 2      3   176560                Google Phone                1        600
# 3      4   176560            Wired Headphones                1      11.99
# 4      5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186849 entries, 0 to 186848
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             186849 non-null  int64
#  1   Order ID          186305 non-null  object
#  2   Product           186305 non-null  object
#  3   Quantity Ordered  186305 non-null  object
#  4   Price Each        186305 non-null  object
#  5   Order Date        186305 non-null  object
#  6   Purchase Address  186305 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 10.0+ MB

# %%
df.isnull().sum()
# Out:
# index                 0
# Order ID            544
# Product             544
# Quantity Ordered    544
# Price Each          544
# Order Date          544
# Purchase Address    544
# dtype: int64

# %%
df.dropna(how='any',inplace=True)

# %%
df.isnull().sum()
# Out:
# index               0
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df['Month'] = df['Order Date'].str[:2]

# %%
df['Month'].unique()
# Out:
# array(['04', '05', 'Or', '08', '09', '12', '01', '02', '03', '07', '06',
#        '11', '10'], dtype=object)

# %%
df[df['Order Date'].str[:2]=='Or']
# Out:
#          index  Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 518        519  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1148      1149  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1154      1155  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2877      2878  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2892      2893  Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...        ...       ...      ...               ...         ...         ...
# 185163  185164  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185550  185551  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186562  186563  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186631  186632  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186737  186738  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address Month
# ...

# %%
df = df[df['Order Date'].str[:2]!='Or']

# %%
df
# Out:
#          index Order ID                     Product Quantity Ordered  \
# 0            0   176558        USB-C Charging Cable                2
# 1            2   176559  Bose SoundSport Headphones                1
# 2            3   176560                Google Phone                1
# 3            4   176560            Wired Headphones                1
# 4            5   176561            Wired Headphones                1
# ...        ...      ...                         ...              ...
# 186844  186845   259353      AAA Batteries (4-pack)                3
# 186845  186846   259354                      iPhone                1
# 186846  186847   259355                      iPhone                1
# 186847  186848   259356      34in Ultrawide Monitor                1
# 186848  186849   259357        USB-C Charging Cable                1
#
#        Price Each      Order Date                         Purchase Address  \
# ...

# %%
df['Month']=df['Month'].astype("int32")
# Out:
# <ipython-input-97-6166ad1fbd20>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month']=df['Month'].astype("int32")

# %%
df.head()
# Out:
#    index Order ID                     Product Quantity Ordered Price Each  \
# 0      0   176558        USB-C Charging Cable                2      11.95
# 1      2   176559  Bose SoundSport Headphones                1      99.99
# 2      3   176560                Google Phone                1        600
# 3      4   176560            Wired Headphones                1      11.99
# 4      5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %%
df['Quantity Ordered'] = df['Quantity Ordered'].astype("int32")
df['Price Each'] = df['Price Each'].astype("float")
# Out:
# <ipython-input-108-9d58d76ad9a8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Quantity Ordered'] = df['Quantity Ordered'].astype("int32")
# <ipython-input-108-9d58d76ad9a8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price Each'] = df['Price Each'].astype("float")

# %%
## Add sales column
df['Sales']= df.loc[:,'Quantity Ordered'] * df.loc[:,'Price Each']
# Out:
# <ipython-input-114-3ee2a56bf486>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sales']= df.loc[:,'Quantity Ordered'] * df.loc[:,'Price Each']

# %%
df.dtypes
# Out:
# index                 int64
# Order ID             object
# Product              object
# Quantity Ordered      int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int32
# Sales               float64
# dtype: object

# %%
##Best Selling Month 

results = df.groupby("Month")['Sales'].sum()

# %%
import matplotlib.pyplot as plt
months = range(1,13)
plt.bar(months,results)
plt.show()

# %%
## What City had the highest number of sales
def get_city(x):
    return x.split(',')[1]

def get_code(x):
    return x.split(',')[2][:3]

# %%
df['City'] = df['Purchase Address'].apply(lambda x : get_city(x) + " "+ get_code(x))
# Out:
# <ipython-input-146-71cd58d91cc0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['City'] = df['Purchase Address'].apply(lambda x : get_city(x) + " "+ get_code(x))

# %%
df
# Out:
#          index Order ID                     Product  Quantity Ordered  \
# 0            0   176558        USB-C Charging Cable                 2
# 1            2   176559  Bose SoundSport Headphones                 1
# 2            3   176560                Google Phone                 1
# 3            4   176560            Wired Headphones                 1
# 4            5   176561            Wired Headphones                 1
# ...        ...      ...                         ...               ...
# 186844  186845   259353      AAA Batteries (4-pack)                 3
# 186845  186846   259354                      iPhone                 1
# 186846  186847   259355                      iPhone                 1
# 186847  186848   259356      34in Ultrawide Monitor                 1
# 186848  186849   259357        USB-C Charging Cable                 1
#
#         Price Each      Order Date                         Purchase Address  \
# ...

# %%
df['City']
# Out:
# 0                 Dallas  TX
# 1                 Boston  MA
# 2            Los Angeles  CA
# 3            Los Angeles  CA
# 4            Los Angeles  CA
#                  ...
# 186844       Los Angeles  CA
# 186845     San Francisco  CA
# 186846     San Francisco  CA
# 186847     San Francisco  CA
# 186848     San Francisco  CA
# Name: City, Length: 185950, dtype: object

# %%
result2=df.groupby("City")['Sales'].sum()

# %%
cities = df['City'].unique()

# %%
plt.bar(cities,result2,color='red')
# Out:
# <BarContainer object of 10 artists>

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])
# Out:
# <ipython-input-160-dfcc85d29b66>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Order Date']=pd.to_datetime(df['Order Date'])

# %%
df['hour']=df['Order Date'].dt.hour
df['Minute']=df['Order Date'].dt.minute
# Out:
# <ipython-input-163-24cc7b66d72b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour']=df['Order Date'].dt.hour
# <ipython-input-163-24cc7b66d72b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Minute']=df['Order Date'].dt.minute

# %%
hours=df['hour'].unique()

# %%
hours
# Out:
# array([ 8, 22, 14,  9, 13,  7, 10, 17, 12, 19, 15, 20, 18,  0, 11, 23, 21,
#         4, 16,  5,  2,  1,  6,  3], dtype=int64)

# %%
df1=df[df['Order ID'].duplicated(keep=False)]

# %%
df1['Grouped']=df1.groupby("Order ID")['Product'].transform(lambda x:','.join(x))
# Out:
# <ipython-input-172-c7668712e92b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Grouped']=df1.groupby("Order ID")['Product'].transform(lambda x:','.join(x))

# %%
df1
# Out:
#          index Order ID                     Product  Quantity Ordered  \
# 2            3   176560                Google Phone                 1
# 3            4   176560            Wired Headphones                 1
# 17          18   176574                Google Phone                 1
# 18          19   176574        USB-C Charging Cable                 1
# 29          30   176585  Bose SoundSport Headphones                 1
# ...        ...      ...                         ...               ...
# 186791  186792   259303       AA Batteries (4-pack)                 1
# 186802  186803   259314            Wired Headphones                 1
# 186803  186804   259314      AAA Batteries (4-pack)                 2
# 186840  186841   259350                Google Phone                 1
# 186841  186842   259350        USB-C Charging Cable                 1
#
#         Price Each          Order Date                       Purchase Address  \
# ...

# %%
grouped=df.groupby("Order Date")['Product'].transform(lambda x:','.join(x))

# %%
grouped
